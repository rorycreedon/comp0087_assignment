# %%
import pandas as pd

train_df = pd.read_pickle(f"data/echr/non-anon_train.pkl")

# %%
train_df
# Out:
#           itemid                                               text  \
# 0      001-60714  The applicant was born in 1943 and lives in La...
# 1     001-100920  The applicant, Mr Panayiotis Panayi, is a Cypr...
# 2      001-77249  The Salvation Army worked officially in Russia...
# 3       001-4589  The applicant is a British national, born in 1...
# 4      001-83374  The applicant was born in 1967 and lives in Li...
# ...          ...                                                ...
# 7095   001-79795  The applicant was born in 1971 and lives in Pl...
# 7096   001-67768  The applicant was born in 1954 and lives in Bo...
# 7097  001-115305  The applicants were born in 1956, 1965, 1986 a...
# 7098  001-105820  The applicant was born in 1929. She was retire...
# 7099   001-22045  The applicant, George Kenneth Mensah, has both...
#
#      violated_articles  violated non_violated_articles all_articles  \
# 0                  [6]      True                    []          [6]
# ...
